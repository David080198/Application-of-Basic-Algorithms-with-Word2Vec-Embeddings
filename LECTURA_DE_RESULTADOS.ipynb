# %% [markdown]
# ## Para regresión logistica

# %%
import os
directorio_actual_1 = os.getcwd()
# Ruta de la carpeta que deseas explorar
ruta_carpeta = directorio_actual_1

# Recorrer la estructura de directorios y archivos de manera recursiva
for directorio_actual, directorios, archivos in os.walk(ruta_carpeta):
    # Verificar si hay archivos con extensión .json en este directorio
    if any(archivo.endswith('.json') for archivo in archivos):
        # Mostrar el directorio actual
        print("\n\n\n\n")
        print("Directorio con archivos .json:", directorio_actual)
        separacion_de_directorio = directorio_actual.split("\\")
        print(f"Directorio_separado: {separacion_de_directorio}")
        # Recorrer los archivos en este directorio
        for archivo in archivos:
            # Verificar si el archivo tiene extensión .json
            if archivo.endswith('.json'):
                # Mostrar el nombre del archivo .json
                print("Nombre del archivo .json:", archivo)
                directorio_json = directorio_actual + "\\" + archivo
                with open(directorio_json, "r") as archivo:
                    datos = json.load(archivo)
                    datos_data = pd.DataFrame.from_dict(datos, orient = 'index')
                    print(datos_data)
                    directorio_de_guardado_pd = directorio_actual + "\\" + separacion_de_directorio[-1] + ".xlsx"
                    directorio_de_guardado_pd_1 = directorio_actual + "\\" + separacion_de_directorio[-1] + "_dataframe" + ".csv"
                    print(f"Dataframe_almacenado en: {directorio_de_guardado_pd}")
                    datos_data.to_excel(directorio_de_guardado_pd, index=True)  # Guardar el DataFrame sin incluir el índice
                    datos_data.to_csv(directorio_de_guardado_pd_1, index=True)  # Guardar el DataFrame sin incluir el índice
# Out:
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_11_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_cruz_word2vect', 'KNN_val_cruz_11_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.381806         0.397423      0.381806
# Experimento_LR_10_test_3          0.376516         0.389805      0.376516
# Experimento_LR_10_test_4          0.382194         0.395949      0.382194
# Experimento_LR_10_test_5          0.384645         0.399825      0.384645
# Experimento_LR_10_test_6          0.386839         0.399799      0.386839
# Experimento_LR_10_test_7          0.382968         0.395241      0.382968
# Experimento_LR_10_test_8          0.388516         0.401321      0.388516
# Experimento_LR_10_test_9          0.389419         0.400956      0.389419
# Experimento_LR_10_test_10         0.386839         0.399551      0.386839
#
#                            f1_media
# Experimento_LR_10_test_2   0.378556
# Experimento_LR_10_test_3   0.372814
# Experimento_LR_10_test_4   0.378809
# Experimento_LR_10_test_5   0.381374
# Experimento_LR_10_test_6   0.383206
# Experimento_LR_10_test_7   0.378993
# Experimento_LR_10_test_8   0.384780
# Experimento_LR_10_test_9   0.385441
# Experimento_LR_10_test_10  0.383003
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_11_vecinos\KNN_val_cruz_11_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_13_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_cruz_word2vect', 'KNN_val_cruz_13_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.383871         0.396315      0.383871
# Experimento_LR_10_test_3          0.382323         0.394992      0.382323
# Experimento_LR_10_test_4          0.387355         0.399047      0.387355
# Experimento_LR_10_test_5          0.384774         0.396277      0.384774
# Experimento_LR_10_test_6          0.386839         0.398899      0.386839
# Experimento_LR_10_test_7          0.387484         0.398596      0.387484
# Experimento_LR_10_test_8          0.385032         0.394694      0.385032
# Experimento_LR_10_test_9          0.388258         0.399254      0.388258
# Experimento_LR_10_test_10         0.387226         0.397755      0.387226
#
#                            f1_media
# Experimento_LR_10_test_2   0.379867
# Experimento_LR_10_test_3   0.378636
# Experimento_LR_10_test_4   0.384395
# Experimento_LR_10_test_5   0.380946
# Experimento_LR_10_test_6   0.383411
# Experimento_LR_10_test_7   0.384194
# Experimento_LR_10_test_8   0.381178
# Experimento_LR_10_test_9   0.384529
# Experimento_LR_10_test_10  0.383377
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_13_vecinos\KNN_val_cruz_13_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_3_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_cruz_word2vect', 'KNN_val_cruz_3_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.342323         0.369370      0.342323
# Experimento_LR_10_test_3          0.345032         0.373159      0.345032
# Experimento_LR_10_test_4          0.344645         0.371458      0.344645
# Experimento_LR_10_test_5          0.347613         0.376639      0.347613
# Experimento_LR_10_test_6          0.346839         0.376233      0.346839
# Experimento_LR_10_test_7          0.343355         0.369715      0.343355
# Experimento_LR_10_test_8          0.346581         0.371111      0.346581
# Experimento_LR_10_test_9          0.344645         0.373265      0.344645
# Experimento_LR_10_test_10         0.348129         0.375627      0.348129
#
#                            f1_media
# Experimento_LR_10_test_2   0.332133
# Experimento_LR_10_test_3   0.335980
# Experimento_LR_10_test_4   0.336586
# Experimento_LR_10_test_5   0.339848
# Experimento_LR_10_test_6   0.339468
# Experimento_LR_10_test_7   0.335545
# Experimento_LR_10_test_8   0.338791
# Experimento_LR_10_test_9   0.336881
# Experimento_LR_10_test_10  0.340864
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_3_vecinos\KNN_val_cruz_3_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_5_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_cruz_word2vect', 'KNN_val_cruz_5_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.358581         0.374239      0.358581
# Experimento_LR_10_test_3          0.356774         0.371866      0.356774
# Experimento_LR_10_test_4          0.356516         0.371960      0.356516
# Experimento_LR_10_test_5          0.361290         0.375180      0.361290
# Experimento_LR_10_test_6          0.358452         0.371972      0.358452
# Experimento_LR_10_test_7          0.362581         0.376221      0.362581
# Experimento_LR_10_test_8          0.359742         0.373004      0.359742
# Experimento_LR_10_test_9          0.358323         0.373714      0.358323
# Experimento_LR_10_test_10         0.360903         0.376436      0.360903
#
#                            f1_media
# Experimento_LR_10_test_2   0.354696
# Experimento_LR_10_test_3   0.352054
# Experimento_LR_10_test_4   0.351849
# Experimento_LR_10_test_5   0.356774
# Experimento_LR_10_test_6   0.353346
# Experimento_LR_10_test_7   0.358221
# Experimento_LR_10_test_8   0.354855
# Experimento_LR_10_test_9   0.353909
# Experimento_LR_10_test_10  0.356803
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_5_vecinos\KNN_val_cruz_5_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_7_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_cruz_word2vect', 'KNN_val_cruz_7_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.372000         0.390070      0.372000
# Experimento_LR_10_test_3          0.368645         0.387308      0.368645
# Experimento_LR_10_test_4          0.370323         0.386763      0.370323
# Experimento_LR_10_test_5          0.371484         0.389692      0.371484
# Experimento_LR_10_test_6          0.371226         0.387253      0.371226
# Experimento_LR_10_test_7          0.373419         0.389722      0.373419
# Experimento_LR_10_test_8          0.365935         0.380374      0.365935
# Experimento_LR_10_test_9          0.370581         0.386801      0.370581
# Experimento_LR_10_test_10         0.370839         0.386008      0.370839
#
#                            f1_media
# Experimento_LR_10_test_2   0.367551
# Experimento_LR_10_test_3   0.364457
# Experimento_LR_10_test_4   0.365109
# Experimento_LR_10_test_5   0.367380
# Experimento_LR_10_test_6   0.367148
# Experimento_LR_10_test_7   0.369165
# Experimento_LR_10_test_8   0.361074
# Experimento_LR_10_test_9   0.366452
# Experimento_LR_10_test_10  0.366118
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_7_vecinos\KNN_val_cruz_7_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_9_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_cruz_word2vect', 'KNN_val_cruz_9_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.373419         0.388129      0.373419
# Experimento_LR_10_test_3          0.377419         0.392507      0.377419
# Experimento_LR_10_test_4          0.379742         0.393640      0.379742
# Experimento_LR_10_test_5          0.380645         0.394366      0.380645
# Experimento_LR_10_test_6          0.379355         0.393032      0.379355
# Experimento_LR_10_test_7          0.377161         0.388813      0.377161
# Experimento_LR_10_test_8          0.378452         0.390708      0.378452
# Experimento_LR_10_test_9          0.379613         0.392560      0.379613
# Experimento_LR_10_test_10         0.377677         0.390120      0.377677
#
#                            f1_media
# Experimento_LR_10_test_2   0.369047
# Experimento_LR_10_test_3   0.373404
# Experimento_LR_10_test_4   0.375955
# Experimento_LR_10_test_5   0.376617
# Experimento_LR_10_test_6   0.375369
# Experimento_LR_10_test_7   0.372801
# Experimento_LR_10_test_8   0.374041
# Experimento_LR_10_test_9   0.375344
# Experimento_LR_10_test_10  0.373188
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_cruz_word2vect\KNN_val_cruz_9_vecinos\KNN_val_cruz_9_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_11_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_sim_word2vect', 'KNN_val_simple_11_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.318710   0.325095  0.318710  0.309736
# Experimento_LR_2_test_0.2   0.316129   0.326804  0.316129  0.311693
# Experimento_LR_3_test_0.3   0.327742   0.337798  0.327742  0.322085
# Experimento_LR_4_test_0.4   0.340000   0.347130  0.340000  0.334048
# Experimento_LR_5_test_0.5   0.331355   0.335443  0.331355  0.322873
# Experimento_LR_6_test_0.6   0.333763   0.340862  0.333763  0.326152
# Experimento_LR_7_test_0.7   0.339724   0.346186  0.339724  0.335531
# Experimento_LR_8_test_0.8   0.340484   0.352624  0.340484  0.329192
# Experimento_LR_9_test_0.9   0.333333   0.353386  0.333333  0.324359
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_11_vecinos\KNN_val_simple_11_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_13_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_sim_word2vect', 'KNN_val_simple_13_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.318710   0.328342  0.318710  0.312885
# Experimento_LR_2_test_0.2   0.321290   0.333235  0.321290  0.317499
# Experimento_LR_3_test_0.3   0.343226   0.352366  0.343226  0.338385
# Experimento_LR_4_test_0.4   0.351935   0.358759  0.351935  0.345808
# Experimento_LR_5_test_0.5   0.351742   0.357329  0.351742  0.343814
# Experimento_LR_6_test_0.6   0.348172   0.355627  0.348172  0.340654
# Experimento_LR_7_test_0.7   0.349677   0.354917  0.349677  0.345161
# Experimento_LR_8_test_0.8   0.342581   0.353972  0.342581  0.332214
# Experimento_LR_9_test_0.9   0.338638   0.352622  0.338638  0.328345
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_13_vecinos\KNN_val_simple_13_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_3_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_sim_word2vect', 'KNN_val_simple_3_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.249032   0.280117  0.249032  0.244752
# Experimento_LR_2_test_0.2   0.238065   0.267251  0.238065  0.233601
# Experimento_LR_3_test_0.3   0.244301   0.272628  0.244301  0.237642
# Experimento_LR_4_test_0.4   0.257419   0.275537  0.257419  0.248166
# Experimento_LR_5_test_0.5   0.257806   0.277172  0.257806  0.249716
# Experimento_LR_6_test_0.6   0.272043   0.283828  0.272043  0.260187
# Experimento_LR_7_test_0.7   0.280737   0.297426  0.280737  0.272673
# Experimento_LR_8_test_0.8   0.290484   0.303439  0.290484  0.275698
# Experimento_LR_9_test_0.9   0.297348   0.318258  0.297348  0.285005
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_3_vecinos\KNN_val_simple_3_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_5_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_sim_word2vect', 'KNN_val_simple_5_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.264516   0.270345  0.264516  0.258146
# Experimento_LR_2_test_0.2   0.267742   0.278013  0.267742  0.262100
# Experimento_LR_3_test_0.3   0.278710   0.289709  0.278710  0.273227
# Experimento_LR_4_test_0.4   0.293226   0.306053  0.293226  0.288875
# Experimento_LR_5_test_0.5   0.295742   0.305377  0.295742  0.290566
# Experimento_LR_6_test_0.6   0.301505   0.308956  0.301505  0.294790
# Experimento_LR_7_test_0.7   0.300645   0.309576  0.300645  0.296835
# Experimento_LR_8_test_0.8   0.314677   0.324415  0.314677  0.304483
# Experimento_LR_9_test_0.9   0.310108   0.326795  0.310108  0.302529
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_5_vecinos\KNN_val_simple_5_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_7_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_sim_word2vect', 'KNN_val_simple_7_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.289032   0.303332  0.289032  0.282963
# Experimento_LR_2_test_0.2   0.295484   0.306421  0.295484  0.288634
# Experimento_LR_3_test_0.3   0.303656   0.314860  0.303656  0.297821
# Experimento_LR_4_test_0.4   0.322258   0.329799  0.322258  0.314651
# Experimento_LR_5_test_0.5   0.322065   0.330442  0.322065  0.314426
# Experimento_LR_6_test_0.6   0.312903   0.318816  0.312903  0.303526
# Experimento_LR_7_test_0.7   0.319263   0.326203  0.319263  0.313453
# Experimento_LR_8_test_0.8   0.328871   0.340283  0.328871  0.317965
# Experimento_LR_9_test_0.9   0.318280   0.341145  0.318280  0.309789
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_7_vecinos\KNN_val_simple_7_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_9_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'KNN_val_sim_word2vect', 'KNN_val_simple_9_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.305806   0.313722  0.305806  0.299411
# Experimento_LR_2_test_0.2   0.295484   0.304125  0.295484  0.290275
# Experimento_LR_3_test_0.3   0.313118   0.322581  0.313118  0.307549
# Experimento_LR_4_test_0.4   0.329355   0.336329  0.329355  0.322890
# Experimento_LR_5_test_0.5   0.329032   0.337485  0.329032  0.322372
# Experimento_LR_6_test_0.6   0.323011   0.329152  0.323011  0.315224
# Experimento_LR_7_test_0.7   0.334009   0.340876  0.334009  0.329888
# Experimento_LR_8_test_0.8   0.333548   0.343227  0.333548  0.322911
# Experimento_LR_9_test_0.9   0.328029   0.347751  0.328029  0.319252
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\KNN_val_sim_word2vect\KNN_val_simple_9_vecinos\KNN_val_simple_9_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\logistica_regression_val_cruz
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'logistica_regression_val_cruz']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.422581         0.408747      0.422581
# Experimento_LR_10_test_3          0.426194         0.413912      0.426194
# Experimento_LR_10_test_4          0.429290         0.416568      0.429290
# Experimento_LR_10_test_5          0.428645         0.416567      0.428645
# Experimento_LR_10_test_6          0.431226         0.419508      0.431226
# Experimento_LR_10_test_7          0.429161         0.417132      0.429161
# Experimento_LR_10_test_8          0.429419         0.417319      0.429419
# Experimento_LR_10_test_9          0.428774         0.417281      0.428774
# Experimento_LR_10_test_10         0.429806         0.418181      0.429806
#
#                            f1_media
# Experimento_LR_10_test_2   0.408825
# Experimento_LR_10_test_3   0.414338
# Experimento_LR_10_test_4   0.417156
# Experimento_LR_10_test_5   0.416844
# Experimento_LR_10_test_6   0.419921
# Experimento_LR_10_test_7   0.417968
# Experimento_LR_10_test_8   0.418186
# Experimento_LR_10_test_9   0.417767
# Experimento_LR_10_test_10  0.418857
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\logistica_regression_val_cruz\logistica_regression_val_cruz.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\logistica_regression_val_sim_
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'logistica_regression_val_sim_']
# Nombre del archivo .json: random_forest_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.440000   0.433799  0.440000  0.435330
# Experimento_LR_2_test_0.2   0.424516   0.415969  0.424516  0.417074
# Experimento_LR_3_test_0.3   0.431828   0.422858  0.431828  0.424080
# Experimento_LR_4_test_0.4   0.425484   0.415651  0.425484  0.416950
# Experimento_LR_5_test_0.5   0.431742   0.420349  0.431742  0.420944
# Experimento_LR_6_test_0.6   0.420860   0.405371  0.420860  0.406288
# Experimento_LR_7_test_0.7   0.415115   0.407587  0.415115  0.396195
# Experimento_LR_8_test_0.8   0.385806   0.411108  0.385806  0.311370
# Experimento_LR_9_test_0.9   0.384803   0.411150  0.384803  0.322037
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\logistica_regression_val_sim_\logistica_regression_val_sim_.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_1000_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_1000_0.0001_0.7']
# Nombre del archivo .json: metricas_1000_0.0001_0.1.json
#                          0
# accuracy          0.480000
# precission        0.454441
# recall            0.466712
# f1                0.448728
# loss              1.057356
# train_accunrancy  0.465520
# test_accyrancy    0.480000
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_1000_0.0001_0.7\RNN_1000_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_1000_0.0001_0.2.json
#                          0
# accuracy          0.465161
# precission        0.456029
# recall            0.460166
# f1                0.439292
# loss              1.090835
# train_accunrancy  0.463871
# test_accyrancy    0.465161
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_1000_0.0001_0.7\RNN_1000_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_1000_0.0001_0.3.json
#                          0
# accuracy          0.431828
# precission        0.439465
# recall            0.430303
# f1                0.420347
# loss              1.358573
# train_accunrancy  0.457327
# test_accyrancy    0.431828
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_1000_0.0001_0.7\RNN_1000_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_1000_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_1000_1e-05_0.7']
# Nombre del archivo .json: metricas_1000_1e-05_0.1.json
#                          0
# accuracy          0.447742
# precission        0.419785
# recall            0.435651
# f1                0.423003
# loss              1.230385
# train_accunrancy  0.414767
# test_accyrancy    0.447742
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_1000_1e-05_0.7\RNN_1000_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_1000_1e-05_0.2.json
#                          0
# accuracy          0.432258
# precission        0.413465
# recall            0.427295
# f1                0.407317
# loss              1.196355
# train_accunrancy  0.416129
# test_accyrancy    0.432258
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_1000_1e-05_0.7\RNN_1000_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_1000_1e-05_0.3.json
#                          0
# accuracy          0.427957
# precission        0.404953
# recall            0.420417
# f1                0.393653
# loss              1.298952
# train_accunrancy  0.413088
# test_accyrancy    0.427957
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_1000_1e-05_0.7\RNN_1000_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_100_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_100_0.0001_0.7']
# Nombre del archivo .json: metricas_100_0.0001_0.1.json
#                          0
# accuracy          0.446452
# precission        0.410304
# recall            0.426769
# f1                0.397021
# loss              1.522415
# train_accunrancy  0.411183
# test_accyrancy    0.446452
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_100_0.0001_0.7\RNN_100_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_100_0.0001_0.2.json
#                          0
# accuracy          0.428387
# precission        0.409015
# recall            0.422212
# f1                0.395640
# loss              1.581409
# train_accunrancy  0.410484
# test_accyrancy    0.428387
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_100_0.0001_0.7\RNN_100_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_100_0.0001_0.3.json
#                          0
# accuracy          0.423226
# precission        0.398176
# recall            0.417031
# f1                0.395066
# loss              1.170272
# train_accunrancy  0.403687
# test_accyrancy    0.423226
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_100_0.0001_0.7\RNN_100_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_100_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_100_1e-05_0.7']
# Nombre del archivo .json: metricas_100_1e-05_0.1.json
#                          0
# accuracy          0.179355
# precission        0.035871
# recall            0.200000
# f1                0.060832
# loss              1.607751
# train_accunrancy  0.202294
# test_accyrancy    0.179355
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_100_1e-05_0.7\RNN_100_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_100_1e-05_0.2.json
#                          0
# accuracy          0.189032
# precission        0.077312
# recall            0.199841
# f1                0.084866
# loss              1.609631
# train_accunrancy  0.198548
# test_accyrancy    0.189032
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_100_1e-05_0.7\RNN_100_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_100_1e-05_0.3.json
#                          0
# accuracy          0.336774
# precission        0.341408
# recall            0.327982
# f1                0.301201
# loss              1.498652
# train_accunrancy  0.316129
# test_accyrancy    0.336774
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_100_1e-05_0.7\RNN_100_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_300_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_300_0.0001_0.7']
# Nombre del archivo .json: metricas_300_0.0001_0.1.json
#                          0
# accuracy          0.437419
# precission        0.422404
# recall            0.435021
# f1                0.422158
# loss              1.318843
# train_accunrancy  0.424946
# test_accyrancy    0.437419
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_300_0.0001_0.7\RNN_300_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_300_0.0001_0.2.json
#                          0
# accuracy          0.448387
# precission        0.436074
# recall            0.448046
# f1                0.440393
# loss              1.305723
# train_accunrancy  0.434355
# test_accyrancy    0.448387
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_300_0.0001_0.7\RNN_300_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_300_0.0001_0.3.json
#                          0
# accuracy          0.441290
# precission        0.423083
# recall            0.437393
# f1                0.426080
# loss              1.209914
# train_accunrancy  0.437972
# test_accyrancy    0.441290
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_300_0.0001_0.7\RNN_300_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_300_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_300_1e-05_0.7']
# Nombre del archivo .json: metricas_300_1e-05_0.1.json
#                          0
# accuracy          0.407742
# precission        0.371202
# recall            0.396133
# f1                0.371571
# loss              1.291235
# train_accunrancy  0.394839
# test_accyrancy    0.407742
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_300_1e-05_0.7\RNN_300_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_300_1e-05_0.2.json
#                          0
# accuracy          0.405161
# precission        0.378481
# recall            0.399002
# f1                0.364550
# loss              1.417994
# train_accunrancy  0.389032
# test_accyrancy    0.405161
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_300_1e-05_0.7\RNN_300_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_300_1e-05_0.3.json
#                          0
# accuracy          0.358710
# precission        0.246036
# recall            0.345679
# f1                0.241669
# loss              1.465780
# train_accunrancy  0.333272
# test_accyrancy    0.358710
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_300_1e-05_0.7\RNN_300_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_500_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_500_0.0001_0.7']
# Nombre del archivo .json: metricas_500_0.0001_0.1.json
#                          0
# accuracy          0.472258
# precission        0.456333
# recall            0.460563
# f1                0.452817
# loss              1.076474
# train_accunrancy  0.451613
# test_accyrancy    0.472258
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_500_0.0001_0.7\RNN_500_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_500_0.0001_0.2.json
#                          0
# accuracy          0.452258
# precission        0.446551
# recall            0.447625
# f1                0.436171
# loss              1.174037
# train_accunrancy  0.447258
# test_accyrancy    0.452258
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_500_0.0001_0.7\RNN_500_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_500_0.0001_0.3.json
#                          0
# accuracy          0.432688
# precission        0.420751
# recall            0.431776
# f1                0.422965
# loss              1.200367
# train_accunrancy  0.449954
# test_accyrancy    0.432688
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_500_0.0001_0.7\RNN_500_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_500_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_500_1e-05_0.7']
# Nombre del archivo .json: metricas_500_1e-05_0.1.json
#                          0
# accuracy          0.436129
# precission        0.401820
# recall            0.416688
# f1                0.387318
# loss              1.178512
# train_accunrancy  0.406882
# test_accyrancy    0.436129
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_500_1e-05_0.7\RNN_500_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_500_1e-05_0.2.json
#                          0
# accuracy          0.443226
# precission        0.423193
# recall            0.439004
# f1                0.416925
# loss              1.112170
# train_accunrancy  0.407419
# test_accyrancy    0.443226
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_500_1e-05_0.7\RNN_500_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_500_1e-05_0.3.json
#                          0
# accuracy          0.344946
# precission        0.239522
# recall            0.340256
# f1                0.257062
# loss              1.495579
# train_accunrancy  0.339171
# test_accyrancy    0.344946
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_500_1e-05_0.7\RNN_500_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_700_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_700_0.0001_0.7']
# Nombre del archivo .json: metricas_700_0.0001_0.1.json
#                          0
# accuracy          0.473548
# precission        0.460211
# recall            0.466358
# f1                0.461212
# loss              1.315697
# train_accunrancy  0.450323
# test_accyrancy    0.473548
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_700_0.0001_0.7\RNN_700_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_700_0.0001_0.2.json
#                          0
# accuracy          0.454839
# precission        0.438354
# recall            0.455955
# f1                0.438561
# loss              1.114004
# train_accunrancy  0.453548
# test_accyrancy    0.454839
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_700_0.0001_0.7\RNN_700_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_700_0.0001_0.3.json
#                          0
# accuracy          0.446882
# precission        0.420681
# recall            0.443159
# f1                0.425307
# loss              1.396571
# train_accunrancy  0.457327
# test_accyrancy    0.446882
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_700_0.0001_0.7\RNN_700_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_700_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'LSTM_Neural_Network', 'RNN_700_1e-05_0.7']
# Nombre del archivo .json: metricas_700_1e-05_0.1.json
#                          0
# accuracy          0.461935
# precission        0.437984
# recall            0.449246
# f1                0.436581
# loss              1.317111
# train_accunrancy  0.413620
# test_accyrancy    0.461935
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_700_1e-05_0.7\RNN_700_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_700_1e-05_0.2.json
#                          0
# accuracy          0.433548
# precission        0.412973
# recall            0.427019
# f1                0.403740
# loss              1.297896
# train_accunrancy  0.412258
# test_accyrancy    0.433548
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_700_1e-05_0.7\RNN_700_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_700_1e-05_0.3.json
#                          0
# accuracy          0.419355
# precission        0.389308
# recall            0.410498
# f1                0.375908
# loss              1.321880
# train_accunrancy  0.405899
# test_accyrancy    0.419355
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\LSTM_Neural_Network\RNN_700_1e-05_0.7\RNN_700_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_0.0001_0.1
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_1000_0.0001_0.1']
# Nombre del archivo .json: resultados_1000_0.0001_0.1.json
#                   0
# accuracy   0.419785
# precision  0.412161
# recall     0.415703
# f1         0.408309
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_0.0001_0.1\RRN_1000_0.0001_0.1.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_0.0001_0.2
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_1000_0.0001_0.2']
# Nombre del archivo .json: resultados_1000_0.0001_0.2.json
#                   0
# accuracy   0.428817
# precision  0.410327
# recall     0.422639
# f1         0.404966
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_0.0001_0.2\RRN_1000_0.0001_0.2.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_0.0001_0.3
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_1000_0.0001_0.3']
# Nombre del archivo .json: resultados_1000_0.0001_0.3.json
#                   0
# accuracy   0.443441
# precision  0.432362
# recall     0.440082
# f1         0.431541
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_0.0001_0.3\RRN_1000_0.0001_0.3.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_1e-05_0.1
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_1000_1e-05_0.1']
# Nombre del archivo .json: resultados_1000_1e-05_0.1.json
#                   0
# accuracy   0.427957
# precision  0.405998
# recall     0.425002
# f1         0.411674
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_1e-05_0.1\RRN_1000_1e-05_0.1.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_1e-05_0.2
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_1000_1e-05_0.2']
# Nombre del archivo .json: resultados_1000_1e-05_0.2.json
#                   0
# accuracy   0.418925
# precision  0.391502
# recall     0.410525
# f1         0.383449
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_1e-05_0.2\RRN_1000_1e-05_0.2.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_1e-05_0.3
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_1000_1e-05_0.3']
# Nombre del archivo .json: resultados_1000_1e-05_0.3.json
#                   0
# accuracy   0.418925
# precision  0.398299
# recall     0.415554
# f1         0.401598
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_1000_1e-05_0.3\RRN_1000_1e-05_0.3.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_100_0.0001_0.1
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_100_0.0001_0.1']
# Nombre del archivo .json: resultados_100_0.0001_0.1.json
#                   0
# accuracy   0.385376
# precision  0.353873
# recall     0.374468
# f1         0.321401
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_100_0.0001_0.1\RRN_100_0.0001_0.1.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_100_0.0001_0.2
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_100_0.0001_0.2']
# Nombre del archivo .json: resultados_100_0.0001_0.2.json
#                   0
# accuracy   0.415484
# precision  0.396698
# recall     0.411850
# f1         0.389060
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_100_0.0001_0.2\RRN_100_0.0001_0.2.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_100_0.0001_0.3
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_100_0.0001_0.3']
# Nombre del archivo .json: resultados_100_0.0001_0.3.json
#                   0
# accuracy   0.371183
# precision  0.319692
# recall     0.357984
# f1         0.279682
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_100_0.0001_0.3\RRN_100_0.0001_0.3.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_100_1e-05_0.1
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_100_1e-05_0.1']
# Nombre del archivo .json: resultados_100_1e-05_0.1.json
#                   0
# accuracy   0.378495
# precision  0.347583
# recall     0.370398
# f1         0.336240
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_100_1e-05_0.1\RRN_100_1e-05_0.1.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Neural_network_classification\RRN_100_1e-05_0.2
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Neural_network_classification', 'RRN_100_1e-05_0.2']
# Nombre del archivo .json: resultados_100_1e-05_0.2.json
#                   0
# accuracy   0.396129
# precision  0.357286
# recall     0.390522
# f1         0.355759
# ...
# Experimento_LR_10_test_4          0.319097         0.318372      0.319097
# Experimento_LR_10_test_5          0.316903         0.318444      0.316903
# Experimento_LR_10_test_6          0.328387         0.328913      0.328387
# Experimento_LR_10_test_7          0.320774         0.320010      0.320774
# Experimento_LR_10_test_8          0.327355         0.327907      0.327355
# Experimento_LR_10_test_9          0.313548         0.315703      0.313548
# Experimento_LR_10_test_10         0.314581         0.315515      0.314581
#
#                            f1_media
# Experimento_LR_10_test_2   0.317176
# Experimento_LR_10_test_3   0.320346
# Experimento_LR_10_test_4   0.318597
# Experimento_LR_10_test_5   0.317454
# Experimento_LR_10_test_6   0.328581
# Experimento_LR_10_test_7   0.320316
# Experimento_LR_10_test_8   0.327548
# Experimento_LR_10_test_9   0.314532
# Experimento_LR_10_test_10  0.314876
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_1_estimators\Random_Forest_val_cruz_1_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_2_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Random_Fores_val_cruz', 'Random_Forest_val_cruz_2_estimators']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.304129         0.343691      0.304129
# Experimento_LR_10_test_3          0.296903         0.331259      0.296903
# Experimento_LR_10_test_4          0.302968         0.334099      0.302968
# Experimento_LR_10_test_5          0.302452         0.342434      0.302452
# Experimento_LR_10_test_6          0.302839         0.337727      0.302839
# Experimento_LR_10_test_7          0.304129         0.346589      0.304129
# Experimento_LR_10_test_8          0.303871         0.339747      0.303871
# Experimento_LR_10_test_9          0.302710         0.332313      0.302710
# Experimento_LR_10_test_10         0.303742         0.337957      0.303742
#
#                            f1_media
# Experimento_LR_10_test_2   0.293265
# Experimento_LR_10_test_3   0.284363
# Experimento_LR_10_test_4   0.290439
# Experimento_LR_10_test_5   0.291987
# Experimento_LR_10_test_6   0.290940
# Experimento_LR_10_test_7   0.292297
# Experimento_LR_10_test_8   0.292865
# Experimento_LR_10_test_9   0.290311
# Experimento_LR_10_test_10  0.290674
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_2_estimators\Random_Forest_val_cruz_2_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_3_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Random_Fores_val_cruz', 'Random_Forest_val_cruz_3_estimators']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.329677         0.346007      0.329677
# Experimento_LR_10_test_3          0.332258         0.354889      0.332258
# Experimento_LR_10_test_4          0.342065         0.361923      0.342065
# Experimento_LR_10_test_5          0.341935         0.363699      0.341935
# Experimento_LR_10_test_6          0.331226         0.351244      0.331226
# Experimento_LR_10_test_7          0.328903         0.345685      0.328903
# Experimento_LR_10_test_8          0.341677         0.358102      0.341677
# Experimento_LR_10_test_9          0.330452         0.348623      0.330452
# Experimento_LR_10_test_10         0.331613         0.350477      0.331613
#
#                            f1_media
# Experimento_LR_10_test_2   0.326744
# Experimento_LR_10_test_3   0.332229
# Experimento_LR_10_test_4   0.339100
# Experimento_LR_10_test_5   0.340874
# Experimento_LR_10_test_6   0.329793
# Experimento_LR_10_test_7   0.326557
# Experimento_LR_10_test_8   0.337916
# Experimento_LR_10_test_9   0.328424
# Experimento_LR_10_test_10  0.330220
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_3_estimators\Random_Forest_val_cruz_3_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_4_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Random_Fores_val_cruz', 'Random_Forest_val_cruz_4_estimators']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.347742         0.359502      0.347742
# Experimento_LR_10_test_3          0.344516         0.354447      0.344516
# Experimento_LR_10_test_4          0.348903         0.358166      0.348903
# Experimento_LR_10_test_5          0.347355         0.357057      0.347355
# Experimento_LR_10_test_6          0.352774         0.362366      0.352774
# Experimento_LR_10_test_7          0.356258         0.368160      0.356258
# Experimento_LR_10_test_8          0.353290         0.363008      0.353290
# Experimento_LR_10_test_9          0.348645         0.358682      0.348645
# Experimento_LR_10_test_10         0.354194         0.364616      0.354194
#
#                            f1_media
# Experimento_LR_10_test_2   0.348748
# Experimento_LR_10_test_3   0.344178
# Experimento_LR_10_test_4   0.347859
# Experimento_LR_10_test_5   0.347788
# Experimento_LR_10_test_6   0.352885
# Experimento_LR_10_test_7   0.356702
# Experimento_LR_10_test_8   0.353557
# Experimento_LR_10_test_9   0.348866
# Experimento_LR_10_test_10  0.354322
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_4_estimators\Random_Forest_val_cruz_4_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_5_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Random_Fores_val_cruz', 'Random_Forest_val_cruz_5_estimators']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.349290         0.359070      0.349290
# Experimento_LR_10_test_3          0.349935         0.355961      0.349935
# Experimento_LR_10_test_4          0.351355         0.358466      0.351355
# Experimento_LR_10_test_5          0.357419         0.364993      0.357419
# Experimento_LR_10_test_6          0.351613         0.357008      0.351613
# Experimento_LR_10_test_7          0.352774         0.359800      0.352774
# Experimento_LR_10_test_8          0.356645         0.364798      0.356645
# Experimento_LR_10_test_9          0.352387         0.357831      0.352387
# Experimento_LR_10_test_10         0.356000         0.362982      0.356000
#
#                            f1_media
# Experimento_LR_10_test_2   0.350141
# Experimento_LR_10_test_3   0.349564
# Experimento_LR_10_test_4   0.350860
# Experimento_LR_10_test_5   0.357786
# Experimento_LR_10_test_6   0.350550
# Experimento_LR_10_test_7   0.352099
# Experimento_LR_10_test_8   0.356444
# Experimento_LR_10_test_9   0.351726
# Experimento_LR_10_test_10  0.356039
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_5_estimators\Random_Forest_val_cruz_5_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_6_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Random_Fores_val_cruz', 'Random_Forest_val_cruz_6_estimators']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.356000         0.364743      0.356000
# Experimento_LR_10_test_3          0.359097         0.367091      0.359097
# Experimento_LR_10_test_4          0.363097         0.371047      0.363097
# Experimento_LR_10_test_5          0.362581         0.369103      0.362581
# Experimento_LR_10_test_6          0.362065         0.369174      0.362065
# Experimento_LR_10_test_7          0.368387         0.377803      0.368387
# Experimento_LR_10_test_8          0.356258         0.366976      0.356258
# Experimento_LR_10_test_9          0.360258         0.366360      0.360258
# Experimento_LR_10_test_10         0.370968         0.379020      0.370968
#
#                            f1_media
# Experimento_LR_10_test_2   0.354629
# Experimento_LR_10_test_3   0.359659
# Experimento_LR_10_test_4   0.361995
# Experimento_LR_10_test_5   0.361758
# Experimento_LR_10_test_6   0.360848
# Experimento_LR_10_test_7   0.367778
# Experimento_LR_10_test_8   0.356156
# Experimento_LR_10_test_9   0.359088
# Experimento_LR_10_test_10  0.370129
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_6_estimators\Random_Forest_val_cruz_6_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_7_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Random_Fores_val_cruz', 'Random_Forest_val_cruz_7_estimators']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.360129         0.365673      0.360129
# Experimento_LR_10_test_3          0.368129         0.371285      0.368129
# Experimento_LR_10_test_4          0.366323         0.372101      0.366323
# Experimento_LR_10_test_5          0.362839         0.369731      0.362839
# Experimento_LR_10_test_6          0.377548         0.382108      0.377548
# Experimento_LR_10_test_7          0.373935         0.376629      0.373935
# Experimento_LR_10_test_8          0.369161         0.372127      0.369161
# Experimento_LR_10_test_9          0.370968         0.375999      0.370968
# Experimento_LR_10_test_10         0.369806         0.373408      0.369806
#
#                            f1_media
# Experimento_LR_10_test_2   0.359618
# Experimento_LR_10_test_3   0.366577
# Experimento_LR_10_test_4   0.365943
# Experimento_LR_10_test_5   0.363266
# Experimento_LR_10_test_6   0.376791
# Experimento_LR_10_test_7   0.371889
# Experimento_LR_10_test_8   0.367739
# Experimento_LR_10_test_9   0.370408
# Experimento_LR_10_test_10  0.369269
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_7_estimators\Random_Forest_val_cruz_7_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_8_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Random_Fores_val_cruz', 'Random_Forest_val_cruz_8_estimators']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.368516         0.374731      0.368516
# Experimento_LR_10_test_3          0.373161         0.378172      0.373161
# Experimento_LR_10_test_4          0.377806         0.380413      0.377806
# Experimento_LR_10_test_5          0.378968         0.382500      0.378968
# Experimento_LR_10_test_6          0.382968         0.388061      0.382968
# Experimento_LR_10_test_7          0.374710         0.379148      0.374710
# Experimento_LR_10_test_8          0.378968         0.381761      0.378968
# Experimento_LR_10_test_9          0.367097         0.371166      0.367097
# Experimento_LR_10_test_10         0.374452         0.377112      0.374452
#
#                            f1_media
# Experimento_LR_10_test_2   0.368886
# Experimento_LR_10_test_3   0.373461
# Experimento_LR_10_test_4   0.376867
# Experimento_LR_10_test_5   0.378343
# Experimento_LR_10_test_6   0.383467
# Experimento_LR_10_test_7   0.374165
# Experimento_LR_10_test_8   0.378184
# Experimento_LR_10_test_9   0.366829
# Experimento_LR_10_test_10  0.373812
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_8_estimators\Random_Forest_val_cruz_8_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_9_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'word2vect_embeddings', 'Random_Fores_val_cruz', 'Random_Forest_val_cruz_9_estimators']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.376000         0.377103      0.376000
# Experimento_LR_10_test_3          0.374581         0.375549      0.374581
# Experimento_LR_10_test_4          0.381032         0.382862      0.381032
# Experimento_LR_10_test_5          0.380516         0.383254      0.380516
# Experimento_LR_10_test_6          0.377935         0.380114      0.377935
# Experimento_LR_10_test_7          0.372387         0.373822      0.372387
# Experimento_LR_10_test_8          0.378323         0.380836      0.378323
# Experimento_LR_10_test_9          0.382968         0.385313      0.382968
# Experimento_LR_10_test_10         0.395355         0.397320      0.395355
#
#                            f1_media
# Experimento_LR_10_test_2   0.374762
# Experimento_LR_10_test_3   0.373009
# Experimento_LR_10_test_4   0.380036
# Experimento_LR_10_test_5   0.379994
# Experimento_LR_10_test_6   0.377284
# Experimento_LR_10_test_7   0.370842
# Experimento_LR_10_test_8   0.377092
# Experimento_LR_10_test_9   0.382496
# Experimento_LR_10_test_10  0.394508
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\word2vect_embeddings\Random_Fores_val_cruz\Random_Forest_val_cruz_9_estimators\Random_Forest_val_cruz_9_estimators.xlsx

# %%
"
